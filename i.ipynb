# %%
import pandas as pd

df = pd.read_csv('/home/cord2108/ITAM/Chatbot/Operador_Eventos/events_output/events_with_tweets.csv')
df
# Out:
#                                                 Event  \
# 0   \nEvent: "¿Podemos ser felices en el trabajo?:...
# 1   \nEvent: Las mujeres en la historia y la histo...
# 2   \nEvent: Sesiones grupales basadas en terapia ...
# 3   \nEvent: Avances y retrocesos en el ejercicio ...
# 4   \nEvent: Ciberseguridad: herramientas del futu...
# 5   \nEvent: Miércoles de Carle | Eventos y Notici...
# 6   \nEvent: Bazar Navideño Makers | Eventos y Not...
# 7   \nEvent: Cierre de Inscripciones - Carrera 6k ...
# 8   \nEvent: VIII Conferencia Anual ICON-S México ...
# 9   \nEvent: Retos y riesgos para la democracia en...
# 10  \nEvent: Sesión informativa en línea de la Mae...
# 11  \nEvent: Seminario CIE- Noel Maurer | Eventos ...
# 12  \nEvent: Seminario de Matemáticas | Eventos y ...
# 13  \nEvent: Reflexiones y propuestas: Las reforma...
#
#                                                 Tweet
# 0   "¿Podemos ser felices en el trabajo? 🤔 La Mtra...
# ...
